# %%
pip install prettymaps
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#                                               0.0/92.5 kB ? eta -:--:--
#      --------------------------               61.4/92.5 kB 3.2 MB/s eta 0:00:01
#      ---------------------------------------- 92.5/92.5 kB 1.7 MB/s eta 0:00:00
# ...
#                                               0.0/1.3 MB ? eta -:--:--
#      --                                       0.1/1.3 MB 2.6 MB/s eta 0:00:01
#      -----                                    0.2/1.3 MB 2.6 MB/s eta 0:00:01
#      --------                                 0.3/1.3 MB 2.1 MB/s eta 0:00:01
#      -----------                              0.4/1.3 MB 2.0 MB/s eta 0:00:01
#      -------------                            0.5/1.3 MB 2.0 MB/s eta 0:00:01
#      ---------------                          0.5/1.3 MB 2.1 MB/s eta 0:00:01
#      ----------------                         0.5/1.3 MB 1.7 MB/s eta 0:00:01
# ...

# %%
import prettymaps as pmap

# %%
plot = pmap.plot('47.550653, 19.096638')
# Out:
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.

# %%
# Draw several regions on the same canvas
pmap.multiplot(
    pmap.Subplot(
        'Belváros, Budapest',
        style={'building': {'palette': ['#49392C', '#E1F2FE', '#98D2EB']}}
    ),
    # Load a global preset
    preset='cb-bf-f',
    # Figure size
    figsize=(12, 12)
)
# Out:
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
# findfont: Font family 'Ubuntu Mono' not found.
